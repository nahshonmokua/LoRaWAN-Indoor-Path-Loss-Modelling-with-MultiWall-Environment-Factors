# %% [markdown]
# <p style="font-family: 'Courier New', Courier, monospace; font-size: 40px; font-weight: bold; color: blue;  text-align: center;">
#   LoRaWAN Path Loss Measurements in an Indoor Setting: DATA SORTING
# </p>

# %% [markdown]
# ###  Notebook Summary
# This Notebook processes unsorted measurement data by:
# - Converting and validating time data.
# - Aggregating daily counts and visualizing the data.
# - Extracting and analyzing unique gateway IDs.
# - Filtering data for a specific gateway ("kerlink001").
# - Deduplicating data based on time and frame count differences.

# %% [markdown]
# ###  1. Import Libraries and Load Data
#
# This cell imports the required libraries and loads the dataset from a CSV file. It then prints basic information about the DataFrame.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv('../all_data_files/unsorted_combined_measurements_data.csv', low_memory=False)
print("Initial DataFrame Info:")
df.info()
# Out:
# Initial DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2313903 entries, 0 to 2313902
# Data columns (total 81 columns):
#  #   Column                                                   Dtype
# ---  ------                                                   -----
#  0   correlation_ids_0                                        object
#  1   device_id                                                object
#  2   end_device_ids_application_ids_application_id            object
#  3   end_device_ids_dev_addr                                  object
#  4   end_device_ids_dev_eui                                   object
#  5   end_device_ids_device_id                                 object
#  6   end_device_ids_join_eui                                  int64
#  7   received_at                                              object
#  8   time                                                     object
#  9   uplink_message_confirmed                                 bool
#  10  uplink_message_consumed_airtime                          object
#  11  uplink_message_decoded_payload_co2                       float64
#  12  uplink_message_decoded_payload_humidity                  float64
#  13  uplink_message_decoded_payload_packetCount               float64
#  14  uplink_message_decoded_payload_pm25                      float64
#  15  uplink_message_decoded_payload_pressure                  float64
#  16  uplink_message_decoded_payload_temperature               float64
#  17  uplink_message_f_cnt                                     float64
#  18  uplink_message_f_port                                    float64
#  19  uplink_message_frm_payload                               object
#  20  uplink_message_network_ids_cluster_address               object
#  21  uplink_message_network_ids_cluster_id                    object
#  22  uplink_message_network_ids_net_id                        int64
#  23  uplink_message_network_ids_ns_id                         object
#  24  uplink_message_network_ids_tenant_id                     object
#  25  uplink_message_received_at                               object
#  26  uplink_message_rx_metadata_0_channel_index               float64
#  27  uplink_message_rx_metadata_0_channel_rssi                float64
#  28  uplink_message_rx_metadata_0_frequency_offset            float64
#  29  uplink_message_rx_metadata_0_gateway_ids_eui             object
#  30  uplink_message_rx_metadata_0_gateway_ids_gateway_id      object
#  31  uplink_message_rx_metadata_0_received_at                 object
#  32  uplink_message_rx_metadata_0_rssi                        float64
#  33  uplink_message_rx_metadata_0_snr                         float64
#  34  uplink_message_rx_metadata_0_time                        object
#  35  uplink_message_rx_metadata_0_timestamp                   float64
#  36  uplink_message_rx_metadata_0_uplink_token                object
#  37  uplink_message_rx_metadata_1_channel_index               float64
#  38  uplink_message_rx_metadata_1_channel_rssi                float64
#  39  uplink_message_rx_metadata_1_frequency_offset            float64
#  40  uplink_message_rx_metadata_1_gateway_ids_eui             object
#  41  uplink_message_rx_metadata_1_gateway_ids_gateway_id      object
#  42  uplink_message_rx_metadata_1_received_at                 object
#  43  uplink_message_rx_metadata_1_rssi                        float64
#  44  uplink_message_rx_metadata_1_snr                         float64
#  45  uplink_message_rx_metadata_1_time                        object
#  46  uplink_message_rx_metadata_1_timestamp                   float64
#  47  uplink_message_rx_metadata_1_uplink_token                object
#  48  uplink_message_rx_metadata_2_channel_index               float64
#  49  uplink_message_rx_metadata_2_channel_rssi                float64
#  50  uplink_message_rx_metadata_2_frequency_offset            float64
#  51  uplink_message_rx_metadata_2_gateway_ids_eui             object
#  52  uplink_message_rx_metadata_2_gateway_ids_gateway_id      object
#  53  uplink_message_rx_metadata_2_received_at                 object
#  54  uplink_message_rx_metadata_2_rssi                        float64
#  55  uplink_message_rx_metadata_2_snr                         float64
#  56  uplink_message_rx_metadata_2_time                        object
#  57  uplink_message_rx_metadata_2_timestamp                   float64
#  58  uplink_message_rx_metadata_2_uplink_token                object
#  59  uplink_message_rx_metadata_3_channel_index               float64
#  60  uplink_message_rx_metadata_3_channel_rssi                float64
#  61  uplink_message_rx_metadata_3_frequency_offset            float64
#  62  uplink_message_rx_metadata_3_gateway_ids_eui             object
#  63  uplink_message_rx_metadata_3_gateway_ids_gateway_id      object
#  64  uplink_message_rx_metadata_3_received_at                 object
#  65  uplink_message_rx_metadata_3_rssi                        float64
#  66  uplink_message_rx_metadata_3_snr                         float64
#  67  uplink_message_rx_metadata_3_timestamp                   float64
#  68  uplink_message_rx_metadata_3_uplink_token                object
#  69  uplink_message_session_key_id                            object
#  70  uplink_message_settings_data_rate_lora_bandwidth         float64
#  71  uplink_message_settings_data_rate_lora_coding_rate       object
#  72  uplink_message_settings_data_rate_lora_spreading_factor  float64
#  73  uplink_message_settings_frequency                        int64
#  74  uplink_message_settings_time                             object
#  75  uplink_message_settings_timestamp                        float64
#  76  uplink_message_version_ids_band_id                       object
#  77  uplink_message_version_ids_brand_id                      object
#  78  uplink_message_version_ids_firmware_version              object
#  79  uplink_message_version_ids_hardware_version              float64
#  80  uplink_message_version_ids_model_id                      object
# dtypes: bool(1), float64(36), int64(3), object(41)
# memory usage: 1.4+ GB

# %% [markdown]
# ### 2. Preprocess Time Data
#
# Convert the 'time' column to datetime (with UTC) and remove invalid entries. Then, extract the date for daily aggregation and plot the unsorted data counts per day.

# %%
# Create a working copy and convert 'time' to datetime
df = df.copy()
df['time'] = pd.to_datetime(df['time'].astype(str), errors='coerce', utc=True)

# Report and drop rows with invalid datetime values
invalid_times = df[df['time'].isna()]
if not invalid_times.empty:
    print(f"Found {len(invalid_times)} invalid time rows; dropping them.")
df = df.dropna(subset=['time'])

# Extract date for aggregation
df['date'] = df['time'].dt.date

# Plot daily counts (unsorted data)
daily_counts_unsorted = df.groupby('date').size()
plt.figure(figsize=(8, 3))
daily_counts_unsorted.plot(kind='line', marker='o', linestyle='-', linewidth=1)
plt.title('Data Points Per Day (Unsorted)')
plt.xlabel('Date')
plt.ylabel('Number of Rows')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# Found 2 invalid time rows; dropping them.

# %% [markdown]
# ### 3. Unique Gateway Analysis
#
# Extract unique gateway IDs from metadata columns (e.g., `uplink_message_rx_metadata_0_gateway_ids_gateway_id`), display their count, list them, and compute the number of rows associated with each gateway.

# %%
# Define gateway metadata columns
gateway_cols = [f'uplink_message_rx_metadata_{i}_gateway_ids_gateway_id' for i in range(3)]
unique_gateways = set()

# Extract unique gateway IDs from available columns
for col in gateway_cols:
    if col in df.columns:
        unique_gateways.update(df[col].dropna().unique())

print("Number of unique gateways:", len(unique_gateways))
print("Unique gateway IDs:", unique_gateways)

# Count rows per gateway
gateway_row_counts = {}
for gw in unique_gateways:
    mask = pd.Series(False, index=df.index)
    for col in gateway_cols:
        if col in df.columns:
            mask |= (df[col] == gw)
    gateway_row_counts[gw] = mask.sum()

print("\nRows per gateway:")
for gw, count in gateway_row_counts.items():
    print(f"{gw}: {count}")
# Out:
# Number of unique gateways: 4
# Unique gateway IDs: {'eui-a84041ffff22def8', 'eui-a84041ffff22dea4', 'kerlink001', 'kerlink-istation'}
#
# Rows per gateway:
# eui-a84041ffff22def8: 1546463
# eui-a84041ffff22dea4: 305952
# kerlink001: 2285771
# kerlink-istation: 15

# %% [markdown]
# ### 4. Filter Data for Target Gateway
#
# Filter the dataset to retain only rows corresponding to the target gateway (`"kerlink001"`). The filtered DataFrame will be used for subsequent deduplication and analysis.

# %%
target_gateway = "kerlink001"
mask = pd.Series(False, index=df.index)
for col in gateway_cols:
    if col in df.columns:
        mask |= (df[col] == target_gateway)

# Filter the DataFrame for the target gateway and reset the index
df_target = df[mask].reset_index(drop=True)
print("Filtered DataFrame shape for target gateway:", df_target.shape)
# Out:
# Filtered DataFrame shape for target gateway: (2285771, 82)

# %% [markdown]
# ### 5. Deduplicate Data Based on Time and Frame Count
#
# Sort the filtered data by device and time, then remove duplicate transmissions where the frame count difference is zero and the time difference is less than 2 seconds. Finally, plot the deduplicated daily counts.

# %%
# Sort by device ID and time
df_target = df_target.sort_values(["end_device_ids_device_id", "time"]).copy()

# Compute time difference and frame counter difference for each device
df_target["dt"] = df_target.groupby("end_device_ids_device_id")["time"].diff().dt.total_seconds()
df_target["df_cnt_diff"] = df_target.groupby("end_device_ids_device_id")["uplink_message_f_cnt"].diff()

# Remove duplicates: where frame count remains unchanged and time diff < 2 seconds
non_duplicate_mask = ~((df_target["df_cnt_diff"] == 0) & (df_target["dt"] < 2.0))
df_dedup = df_target[non_duplicate_mask].copy()

# Clean up intermediate columns
df_dedup.drop(columns=["dt", "df_cnt_diff"], inplace=True, errors="ignore")
df_dedup.reset_index(drop=True, inplace=True)

print("Original shape:", df_target.shape)
print("Deduplicated shape:", df_dedup.shape)

# Plot daily counts for deduplicated data
df_dedup["date"] = df_dedup["time"].dt.date
daily_counts_dedup = df_dedup.groupby("date").size()
plt.figure(figsize=(8, 3))
daily_counts_dedup.plot(kind='line', marker='o', linestyle='-', linewidth=1)
plt.title('Data Points Per Day (Deduplicated)')
plt.xlabel('Date')
plt.ylabel('Number of Rows')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# Original shape: (2285771, 84)
# Deduplicated shape: (1715881, 82)

# %% [markdown]
# ### 6. Save Cleaned Data and Preview
#
# Save the cleaned, deduplicated dataset to a CSV file and display the last 10 rows as a preview.

# %%
# Save the cleaned data to CSV
df_dedup.to_csv('../all_data_files/combined_measurements_data.csv', index=False)
print("Data cleaning and deduplication completed. CSV file saved.")

# Display the tail of the deduplicated DataFrame
df_dedup.tail(10)
